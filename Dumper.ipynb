# %%
pip install datafreeze
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install normality
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from datafreeze import freeze

# %%
import dataset

db = dataset.connect("sqlite:///Bali.db")
result = db['TabelBali'].all()
freeze(result, format='csv', filename='Bali.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv("Bali.csv")

# %%
df
# Out:
#           id               id_str              created  \
# 0          1  1257617142213570560  2020-05-05T10:24:26
# 1          2  1257617158630068224  2020-05-05T10:24:30
# 2          3  1257617212027867142  2020-05-05T10:24:43
# 3          4  1257617368550785025  2020-05-05T10:25:20
# 4          5  1257617404730863617  2020-05-05T10:25:29
# ...      ...                  ...                  ...
# 28450  28451  1262911733666021376  2020-05-20T01:03:15
# 28451  28452  1262911896954396673  2020-05-20T01:03:54
# 28452  28453  1262911918144016385  2020-05-20T01:03:59
# 28453  28454  1262911938142535680  2020-05-20T01:04:04
# 28454  28455  1262911972644917248  2020-05-20T01:04:12
#
#                                                     text  fav_count  \
# 0                         isssss https://t.co/6DCTSCLsrR          0
# 1                                      @prama_tee Wkwkwk          0
# 2      terima kasih ka siska \n.\ngrabfood\ngofood\ns...          0
# ...
