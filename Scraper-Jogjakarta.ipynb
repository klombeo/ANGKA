# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import dataset
from sqlalchemy.exc import ProgrammingError

# %%
class StdOutListener(StreamListener):
    def on_status(self, status):
        print(status.text)
        if status.retweeted:
            return
        
        id_str = status.id_str
        created = status.created_at
        text = status.text
        fav = status.favorite_count
        name = status.user.screen_name
        description = status.user.description
        loc = status.user.location
        user_created = status.user.created_at
        followers = status.user.followers_count

        table = db['TabelJogjakarta']
        
        try:
            table.insert(dict(
                id_str=id_str,
                created=created,
                text=text,
                fav_count=fav,
                user_name=name,
                user_description=description,
                user_location=loc,
                user_created=user_created,
                user_followers=followers,
            ))
        except ProgrammingError as err:
            print(err)
    

    def on_error(self, status_code):
        if status_code == 420:
            return False

# %%
from __future__ import absolute_import, print_function

consumer_key = "l8foc5sgGzS2qbYBhNbHVWHlf"
consumer_secret = "EOzD20rUSa1mITEa04YFRC1KCJQXlwdhPvFbDp6kbROZizH93o"
access_token = "1251608822042542080-nyzk8Owmyb4PaBBiOJpP3CNBhNwGaL"
access_token_secret = "pnGt2BE84VOKvOzlWLGrY7o1kuggw9RyRFuKoDRZsBxxx"

"""
The code for our listener class above goes here!
"""

if __name__ == '__main__':
    db = dataset.connect("sqlite:///Jogjakarta.db")
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    Banten = [105.1069,-7.4118,106.5351,-5.8513]
    Jakarta = [106.535138,-7.45539,106.985577,-5.397594]
    JawaBarat = [106.9856,-7.8327,108.7501,-5.8967]
    JawaTengah = [108.7501,-7.5388,111.3291,-5.6985]
    Jogjakarta = [108.7501,-8.291,111.3291,-7.5388]
    JawaTimur = [111.3291,-8.7745,114.4307,-5.4117]
    Bali = [114.430654,-8.853224,115.820425,-7.463961]
    Papua = [134.9732,-9.2,140.9498,-0.6046]
    stream = Stream(auth, l)
    stream.filter(locations= Jogjakarta)
# Out:
# air tak selalu jernih begitu juga ucapanku...
# @rayhanprimaaa Aku ra nengapa ngapa koh😂
# Siapa tau mutualanku ditwitter mau beli pepes ikan ku.
# Masakan sendiri kok, jadi aman 🥳
# Open Order Hari Jumat yaaa… https://t.co/rTR6tAFi1U
# Poso poso ngeleh marai goblokk:)
# @depasean beranda
# Ini kurva laju ekonomi dan kesejahteraan rakyat kan, bagus dong malah.
# Ini kategorinya pelecehan seksual kan? Coba dibalik korbanny cewek.
# @jasmoone no no , relate pasti
# @aryanto_three @inggitpar @hanssakti @stevenindraw Ya Alloh aku katut wkwkwk
# @youradmirerr_ Ga mau
# @FahmiZulkarna12 Hahahaha ajg ajg ▄︻̷̿┻̿═━一
# @Isma_Ismais Ga mau
# Aku benci hujan
# epic comeback
# Entah apa yang merasuki
# @penyukata__ Ya gtu lah
# Cool 😎
# @coklatlumerrrr Menua bersamamu
# `mnfs
# eh yang bikin font dari tulisan tangan sendiri itu gimana ya, webnya apa
# @ilytigarebo Menua bersamamu
# ...
